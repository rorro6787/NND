# %%
from SAES.latex_generation.stats_table import Friedman
from SAES.latex_generation.stats_table import Wilcoxon
from SAES.plots.boxplot import Boxplot
from SAES.plots.CDplot import CDplot

import pandas as pd

# %%
"""
In order to generate the HTML code from the notebook, write this command in the terminal:
jupyter nbconvert --to html --no-input multiobjective_optimization.ipynb

If you do not have jupyter installed, you can use the python terminal:
python -m nbconvert --to html --no-input multiobjective_optimization.ipynb
""";

# %%
# Load the experiment data
experimentData = pd.read_csv('data.csv')
metrics = pd.read_csv('metrics.csv')

# %% [markdown]
# # Comparative study of multi-objective metaheuristics

# %% [markdown]
# ## DSC quality indicator

# %%
metric = "IoU"

# %% [markdown]
# ## Medians table

# %%
friedman = Friedman(experimentData, metrics, metric)
friedman.show()
# Out:
# <style type="text/css">
# #T_57a08_row0_col1, #T_57a08_row1_col1, #T_57a08_row2_col1, #T_57a08_row3_col1, #T_57a08_row4_col1, #T_57a08_row5_col1, #T_57a08_row6_col1, #T_57a08_row7_col1, #T_57a08_row8_col0, #T_57a08_row9_col1, #T_57a08_row10_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_57a08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57a08_level0_col0" class="col_heading level0 col0" >nnUNet2D</th>
#       <th id="T_57a08_level0_col1" class="col_heading level0 col1" >nnUNet3D</th>
#       <th id="T_57a08_level0_col2" class="col_heading level0 col2" >Friedman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57a08_level0_row0" class="row_heading level0 row0" >GlobalV</th>
#       <td id="T_57a08_row0_col0" class="data row0 col0" >6.0231e-01</td>
#       <td id="T_57a08_row0_col1" class="data row0 col1" >6.2594e-01</td>
#       <td id="T_57a08_row0_col2" class="data row0 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row1" class="row_heading level0 row1" >GlovalT</th>
#       <td id="T_57a08_row1_col0" class="data row1 col0" >5.4608e-01</td>
#       <td id="T_57a08_row1_col1" class="data row1 col1" >6.2084e-01</td>
#       <td id="T_57a08_row1_col2" class="data row1 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row2" class="row_heading level0 row2" >P47T1</th>
#       <td id="T_57a08_row2_col0" class="data row2 col0" >6.3787e-01</td>
#       <td id="T_57a08_row2_col1" class="data row2 col1" >6.7905e-01</td>
#       <td id="T_57a08_row2_col2" class="data row2 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row3" class="row_heading level0 row3" >P47T2</th>
#       <td id="T_57a08_row3_col0" class="data row3 col0" >3.6535e-01</td>
#       <td id="T_57a08_row3_col1" class="data row3 col1" >5.5262e-01</td>
#       <td id="T_57a08_row3_col2" class="data row3 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row4" class="row_heading level0 row4" >P48T1</th>
#       <td id="T_57a08_row4_col0" class="data row4 col0" >5.8218e-01</td>
#       <td id="T_57a08_row4_col1" class="data row4 col1" >6.9028e-01</td>
#       <td id="T_57a08_row4_col2" class="data row4 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row5" class="row_heading level0 row5" >P49T1</th>
#       <td id="T_57a08_row5_col0" class="data row5 col0" >5.0700e-01</td>
#       <td id="T_57a08_row5_col1" class="data row5 col1" >5.5596e-01</td>
#       <td id="T_57a08_row5_col2" class="data row5 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row6" class="row_heading level0 row6" >P50T1</th>
#       <td id="T_57a08_row6_col0" class="data row6 col0" >5.3387e-01</td>
#       <td id="T_57a08_row6_col1" class="data row6 col1" >7.1394e-01</td>
#       <td id="T_57a08_row6_col2" class="data row6 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row7" class="row_heading level0 row7" >P51T1</th>
#       <td id="T_57a08_row7_col0" class="data row7 col0" >6.4366e-01</td>
#       <td id="T_57a08_row7_col1" class="data row7 col1" >7.1406e-01</td>
#       <td id="T_57a08_row7_col2" class="data row7 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row8" class="row_heading level0 row8" >P52T1</th>
#       <td id="T_57a08_row8_col0" class="data row8 col0" >7.3954e-01</td>
#       <td id="T_57a08_row8_col1" class="data row8 col1" >7.3097e-01</td>
#       <td id="T_57a08_row8_col2" class="data row8 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row9" class="row_heading level0 row9" >P53T1</th>
#       <td id="T_57a08_row9_col0" class="data row9 col0" >3.9645e-01</td>
#       <td id="T_57a08_row9_col1" class="data row9 col1" >4.5853e-01</td>
#       <td id="T_57a08_row9_col2" class="data row9 col2" >+</td>
#     </tr>
#     <tr>
#       <th id="T_57a08_level0_row10" class="row_heading level0 row10" >P53T2</th>
#       <td id="T_57a08_row10_col0" class="data row10 col0" >4.7836e-01</td>
#       <td id="T_57a08_row10_col1" class="data row10 col1" >5.3138e-01</td>
#       <td id="T_57a08_row10_col2" class="data row10 col2" >+</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Wilcoxon rank-sum test table

# %%
wilcoxon = Wilcoxon(experimentData, metrics, metric)
wilcoxon.show()
# Out:
# <style type="text/css">
# #T_83bd2_row0_col0 {
#   font-size: 12px;
#   font-family: monospace;
# }
# </style>
# <table id="T_83bd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83bd2_level0_col0" class="col_heading level0 col0" >nnUNet3D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83bd2_level0_row0" class="row_heading level0 row0" >nnUNet2D</th>
#       <td id="T_83bd2_row0_col0" class="data row0 col0" >--------+--</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Critical distance ranking

# %%
cdplot = CDplot(experimentData, metrics, metric)
cdplot.show()

# %% [markdown]
# ## Boxplots

# %%
boxplot = Boxplot(experimentData, metrics, metric)
boxplot.show_all_instances()

# %%
from SAES.plots.Pplot import Pplot

# %%
Pplot(experimentData, metrics, metric, bayesian_test="rank").show("nnUNet2D", "nnUNet3D")
